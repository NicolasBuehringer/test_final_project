# %%
# %load_ext autoreload
# %autoreload 2
import sys
sys.path.append("twint/")

# %%
# !pip3 install --upgrade -e git+https://github.com/twintproject/twint.git@origin/master#egg=twint
# Out:
# Obtaining twint from git+https://github.com/twintproject/twint.git@origin/master#egg=twint
#   Cloning https://github.com/twintproject/twint.git (to revision origin/master) to /Users/nicolas/.pyenv/versions/3.8.6/envs/lewagon/src/twint
#   Running command git clone -q https://github.com/twintproject/twint.git /Users/nicolas/.pyenv/versions/3.8.6/envs/lewagon/src/twint
#   WARNING: Did not find branch or tag 'origin/master', assuming revision or ref.
#   Running command git checkout -q origin/master
#   Resolved https://github.com/twintproject/twint.git to commit origin/master
# ...
#   Attempting uninstall: twint
#     Found existing installation: twint 2.1.20
#     Uninstalling twint-2.1.20:
#       Successfully uninstalled twint-2.1.20
#   Running setup.py develop for twint
# ...

# %%
import twint
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_14932/3064374937.py in <module>
# ----> 1 import twint
#
# ModuleNotFoundError: No module named 'twint'

# %%
import pandas as pd
import nest_asyncio
import matplotlib.pyplot as plt
nest_asyncio.apply()
pd.set_option('display.max_colwidth', None)

# %%
twint.Config()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/34/1yvhb8vj085g3m5tpn1x91d80000gn/T/ipykernel_14932/1679206183.py in <module>
# ----> 1 twint.Config()
#
# NameError: name 'twint' is not defined

# %%
config = twint.Config()
# config.Lang = "fr"
# config.Min_likes= 10
german_party=["CDU"]
#"SPD", "Gruenen", "FDP", "AfD", "LINKE"
for party in german_party:
    print(f"{party}")
    config.Search = party
    config.Limit = 100_000
    config.Min_likes= 10
    config.Lang = "de"
    config.Since ='2021-08-01 12:00:00'
    config.Until ='2021-08-18 12:00:00'
    config.Store_csv = True
    config.Hide_output = True
    config.Output = f"{party}_german_party.csv"
    twint.run.Search(config)
# Out:
# CDU
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 1.0 secs
# CRITICAL:root:twint.run:Twint:Feed:noDataExpecting value: line 1 column 1 (char 0)
# sleeping for 8.0 secs
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/twint/run.py in Feed(self)
#      64                 elif self.config.TwitterSearch:
# ---> 65                     self.feed, self.init = feed.Json(response)
#      66                 break
#
# ~/.pyenv/versions/3.8.6/envs/lewagon/lib/python3.8/site-packages/twint/feed.py in Json(response)
#      41     logme.debug(__name__+':Json')
# ---> 42     json_response = loads(response)
#      43     html = json_response["items_html"]
#
# ...

# %%
df_CDU=pd.read_csv(f"CDU_german_party.csv")
# df_SPD=pd.read_csv(f"SPD_german_party.csv")
# df_Grünen=pd.read_csv(f"Grünen_german_party.csv")
# df_FDP=pd.read_csv(f"FDP_german_party.csv")
# df_AFD=pd.read_csv(f"AFD_german_party.csv")

# %%
df_CDU.columns
# Out:
# Index(['id', 'conversation_id', 'created_at', 'date', 'time', 'timezone',
#        'user_id', 'username', 'name', 'place', 'tweet', 'language', 'mentions',
#        'urls', 'photos', 'replies_count', 'retweets_count', 'likes_count',
#        'hashtags', 'cashtags', 'link', 'retweet', 'quote_url', 'video',
#        'thumbnail', 'near', 'geo', 'source', 'user_rt_id', 'user_rt',
#        'retweet_id', 'reply_to', 'retweet_date', 'translate', 'trans_src',
#        'trans_dest'],
#       dtype='object')

# %%
df_CDU=pd.read_csv(f"CDU_german_party.csv")
df_CDU[df_CDU["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions"]]
# Out:
#              date                   name  \
# 1      2021-08-18                      T
# 2      2021-08-18      Christian Schmidt
# 3      2021-08-18           Revoluzza💙🇦🇹
# 5      2021-08-18         EnvoyOfIzalith
# 6      2021-08-18                  Peter
# ...           ...                    ...
# 16815  2021-08-10  digitalFarmer🏳️‍🌈🏳️‍🌈
# 16816  2021-08-10           Peter Schaar
# 16818  2021-08-10           Jan S. Weber
# 16819  2021-08-10     Tim Schoolmann🏳️‍🌈
# 16820  2021-08-10               Ralph H.
#
#                                                    tweet  likes_count  \
# 1      Ich werde mir KEINE Dritte Spritze geben lasse...            0
# 2      @polenz_r @Karl_Lauterbach Wie kommen die denn...            0
# 3      @CDU verdammt nochmal, Sie haben keine Chance ...            0
# 5      @rleinf Die Schöpfung bewahren mit der @CDU. M...            0
# 6      @pelsenir @miriam_vollmer Mag sein, aber was k...            1
# ...

# %%
df_SPD=pd.read_csv(f"SPD_german_party.csv")
df_SPD[df_SPD["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions"]]
# Out:
#             date                              name  \
# 0     2021-08-18                       Wikinaut 🔥🌋
# 6     2021-08-18  Richard Bercanay ☕️☕️ 💉 💉 (mRNA)
# 8     2021-08-18                           Gargari
# 11    2021-08-18                             Fiona
# 12    2021-08-18             Darkness inside 🤜🏻🤛🏿😷
# ...          ...                               ...
# 8605  2021-08-10                        UnionWatch
# 8606  2021-08-10                  Wolfgang Schmidt
# 8607  2021-08-10               R.H. (Jetzt mit 5G)
# 8608  2021-08-10                        UnionWatch
# 8609  2021-08-10                Tim Schoolmann🏳️‍🌈
#
#                                                   tweet  likes_count  retweet  \
# 0               @doktorhulk @ClaasGefroi Franzi auf SPD            0    False
# 6     @danielreitzig Wir denken auch 39 Tage vor der...            0    False
# 8     @PeterRNeumann @ArminLaschet Mach dich nicht z...            0    False
# ...

# %%
df_Gruenen=pd.read_csv(f"Gruenen_german_party.csv")
df_Gruenen[df_Gruenen["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions"]]
# Out:
#             date                          name  \
# 0     2021-08-18                       Patriot
# 1     2021-08-18            Götz Frömming, MdB
# 2     2021-08-18                 Germanniag 🛡️
# 3     2021-08-18              Gegen die Grünen
# 4     2021-08-18                          BR24
# ...          ...                           ...
# 2634  2021-08-13                Tiemo Wölken🇪🇺
# 2635  2021-08-13                  🎉Klawüppke 🍓
# 2636  2021-08-13           Christian F. Müller
# 2637  2021-08-13  NoCovid 🇩🇪 🇪🇺 🌍 YesToNoCovid
# 2638  2021-08-13               Die Grünen Wien
#
#                                                   tweet  likes_count  retweet  \
# 0     Unter Merkel hat Deutschland nur noch fertig d...          190    False
# 1     Die @AfDimBundestag hatte sich für die Aufnahm...           84    False
# 2     @landnrw @ArminLaschet Nun spricht #Laschet pl...           11    False
# 3     Tjaaa, könnt es gerne weiterverbreiten :) Sein...          187    False
# ...

# %%
config.Search = "FDP"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-01 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.Output = "FDP_german_party.csv"
twint.run.Search(config)
df_FDP=pd.read_csv("FDP_german_party.csv")
df_FDP[df_FDP["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions"]]
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#             date                                     name  \
# 0     2021-08-18  Na hoppla embee Naturjogurt stichfest 🔥
# 3     2021-08-18                 Uwe Alfred 2 mal geimpft
# 5     2021-08-18                                     Alex
# 6     2021-08-18                            Furkan Oguz 💉
# 7     2021-08-18                     Nicolas A. Rimoldi 💜
# ...          ...                                      ...
# 6415  2021-08-10                                Marius N.
# 6416  2021-08-10                           Junge Freiheit
# 6417  2021-08-10                              Gerd Plorin
# 6418  2021-08-10                                Giaaa 🦷🔨💥
# 6419  2021-08-10                           Stefan Henning
#
#                                                   tweet  likes_count  retweet  \
# 0     Ich beömmel mich schon sehr darüber wie viel K...           12    False
# ...

# %%
config.Search = "CDU"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-17 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.Output = "CDU_german_party.csv"
twint.run.Search(config)
df_CDU=pd.read_csv("CDU_german_party.csv")
df_CDU[df_CDU["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions"]]
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#            date                      name  \
# 0    2021-08-18               Erik Flügge
# 1    2021-08-18                  Kid Doom
# 2    2021-08-18            Hubertus Leben
# 3    2021-08-18                UnionWatch
# 4    2021-08-18  Uwe Alfred 2 mal geimpft
# ..          ...                       ...
# 570  2021-08-17              SugammaHex 🔴
# 571  2021-08-17               Nicolesmith
# 572  2021-08-17                    Wyland
# 573  2021-08-17                  hanno 💉💉
# 574  2021-08-17                    Flexor
#
#                                                  tweet  likes_count  retweet  \
# 0    Der große, große, große Denkfehler in der #CDU...         1404    False
# 1    @CDU Wenn man sich selbst lobt, während alle s...           19    False
# 2    @CDU @ArminLaschet Und gleichzeitig hält die C...           22    False
# ...

# %%
config.Search = "SPD"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-17 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.Output = "SPD_german_party.csv"
twint.run.Search(config)
df_SPD=pd.read_csv("SPD_german_party.csv")
df_SPD[df_SPD["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions"]]
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#            date                                              name  \
# 1    2021-08-18                                         Norbert 🎸
# 2    2021-08-18                                              NABU
# 3    2021-08-18                                 Patrick L. Schunn
# 5    2021-08-18                                   Henriette Quade
# 6    2021-08-18                          Uwe Alfred 2 mal geimpft
# ..          ...                                               ...
# 582  2021-08-17                                               Kai
# 583  2021-08-17  Olle Opa Kowalski, Seelen kann man nicht Kleben.
# 584  2021-08-17                              Lower Class Magazine
# 585  2021-08-17                                          hanno 💉💉
# 586  2021-08-17                                   Philipp Kursawe
#
#                                                  tweet  likes_count  retweet  \
# ...

# %%
config.Search = "Gruenen"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-17 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.Output = "Gruenen_german_party.csv"
twint.run.Search(config)
df_Gruenen=pd.read_csv("Gruenen_german_party.csv")
df_Gruenen[df_Gruenen["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions"]]
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#            date                name  \
# 0    2021-08-18             Patriot
# 1    2021-08-18  Götz Frömming, MdB
# 2    2021-08-18       Germanniag 🛡️
# 3    2021-08-18    Gegen die Grünen
# 4    2021-08-18                BR24
# ..          ...                 ...
# 422  2021-08-17            hanno 💉💉
# 423  2021-08-17               Wasap
# 424  2021-08-17              Flexor
# 425  2021-08-17    neulandrebellen!
# 426  2021-08-17       TheRealTom™ 🙂
#
#                                                  tweet  likes_count  retweet  \
# 0    Unter Merkel hat Deutschland nur noch fertig d...          198    False
# 1    Die @AfDimBundestag hatte sich für die Aufnahm...           86    False
# 2    @landnrw @ArminLaschet Nun spricht #Laschet pl...           11    False
# 3    Tjaaa, könnt es gerne weiterverbreiten :) Sein...          191    False
# ...

# %%
config.Search = "FDP"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-17 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.Output = "FDP_german_party.csv"
twint.run.Search(config)
df_FDP=pd.read_csv("FDP_german_party.csv")
df_FDP[df_FDP["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions"]]
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#            date                                     name  \
# 0    2021-08-18  Na hoppla embee Naturjogurt stichfest 🔥
# 3    2021-08-18                 Uwe Alfred 2 mal geimpft
# 5    2021-08-18                                     Alex
# 6    2021-08-18                            Furkan Oguz 💉
# 7    2021-08-18                     Nicolas A. Rimoldi 💜
# ..          ...                                      ...
# 582  2021-08-17                              Niclas Vogt
# 583  2021-08-17                                  phoenix
# 586  2021-08-17            Marie-Agnes Strack-Zimmermann
# 588  2021-08-17                                     Y🗽🇪🇺
# 591  2021-08-17             🔴🔴🔴Dustin Miesfeld🏳️‍🌈🏳️‍🌈💉💉
#
#                                                  tweet  likes_count  retweet  \
# 0    Ich beömmel mich schon sehr darüber wie viel K...           12    False
# ...

# %%
config.Search = "AfD"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-17 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.Output = "AfD_german_party.csv"
twint.run.Search(config)
df_AfD=pd.read_csv("AfD_german_party.csv")
df_AfD[df_AfD["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions"]]
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#            date                                  name  \
# 0    2021-08-18                               Patriot
# 1    2021-08-18                                linkde
# 2    2021-08-18                              Helfried
# 3    2021-08-18      Kaiserin Ranni #TeamDragonBug 🐉🐞
# 4    2021-08-18                         Germanniag 🛡️
# ..          ...                                   ...
# 627  2021-08-17                        Philip Kreißel
# 628  2021-08-17  PIRATEN Zittau Accountinh. J. Krüger
# 629  2021-08-17                         Tommes Frites
# 630  2021-08-17                                Flexor
# 631  2021-08-17                         TheRealTom™ 🙂
#
#                                                  tweet  likes_count  retweet  \
# 0    Unter Merkel hat Deutschland nur noch fertig d...          198    False
# ...

# %%
config.Search = "LINKE"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-17 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.Output = "LINKE_german_party.csv"
twint.run.Search(config)
df_LINKE=pd.read_csv("LINKE_german_party.csv")
df_LINKE[df_LINKE["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "mentions", "geo"]]
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.
#            date                            name  \
# 0    2021-08-18                  Stefan 💉 Soher
# 2    2021-08-18                       AstroAtze
# 3    2021-08-18                             Ben
# 4    2021-08-18                     Junge Linke
# 5    2021-08-18                DennisKBerlin 💉💉
# ..          ...                             ...
# 309  2021-08-17                Die andere Wende
# 310  2021-08-17      DIE LINKE. Burgenlandkreis
# 311  2021-08-17                   Orkan ÖZDEMIR
# 313  2021-08-17  Antifaschistische Linke Bochum
# 314  2021-08-17           Fee Linke für Parität
#
#                                                  tweet  likes_count  retweet  \
# 0    @i_am_fabs Die Frage ist, wann ist der Punkt e...           22    False
# 2    ach ja die 5.2% linke wird die politk natürlic...           10    False
# ...

# %%
df_LINKE[df_LINKE["language"]=="de"][["date","name","tweet", "likes_count", "retweet", "link", "geo"]]
# Out:
#            date                            name  \
# 0    2021-08-18                  Stefan 💉 Soher
# 2    2021-08-18                       AstroAtze
# 3    2021-08-18                             Ben
# 4    2021-08-18                     Junge Linke
# 5    2021-08-18                DennisKBerlin 💉💉
# ..          ...                             ...
# 309  2021-08-17                Die andere Wende
# 310  2021-08-17      DIE LINKE. Burgenlandkreis
# 311  2021-08-17                   Orkan ÖZDEMIR
# 313  2021-08-17  Antifaschistische Linke Bochum
# 314  2021-08-17           Fee Linke für Parität
#
#                                                  tweet  likes_count  retweet  \
# 0    @i_am_fabs Die Frage ist, wann ist der Punkt e...           22    False
# 2    ach ja die 5.2% linke wird die politk natürlic...           10    False
# 3    @Moritz_Wichmann @felixsschulz cool ich finde ...           24    False
# ...

# %%
df_LINKE[df_LINKE["language"]=="de" ][["date","name","tweet", "likes_count", "retweet", "link"]]
# Out:
#            date                            name  \
# 0    2021-08-18                  Stefan 💉 Soher
# 2    2021-08-18                       AstroAtze
# 3    2021-08-18                             Ben
# 4    2021-08-18                     Junge Linke
# 5    2021-08-18                DennisKBerlin 💉💉
# ..          ...                             ...
# 309  2021-08-17                Die andere Wende
# 310  2021-08-17      DIE LINKE. Burgenlandkreis
# 311  2021-08-17                   Orkan ÖZDEMIR
# 313  2021-08-17  Antifaschistische Linke Bochum
# 314  2021-08-17           Fee Linke für Parität
#
#                                                                                                                                                                                                                                                                                                                        tweet  \
# ...

# %%
config.Search = "LINKE"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-08 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.Output = "week_LINKE_german_party.csv"
twint.run.Search(config)
df_LINKE_week=pd.read_csv("week_LINKE_german_party.csv")
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
config.Search = "AfD"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-08 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.Output = "week_AfD_german_party.csv"
twint.run.Search(config)
df_AfD_week=pd.read_csv("week_AfD_german_party.csv")
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
config.Search = "FDP"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-08 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.lang= "de"
config.Output = "week_FDP_german_party.csv"
twint.run.Search(config)
df_FDP_week=pd.read_csv("week_FDP_german_party.csv")
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
config.Search = "Gruenen"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-08 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.lang= "de"
config.Output = "week_Gruenen_german_party.csv"
twint.run.Search(config)
df_Gruenen_week=pd.read_csv("week_Gruenen_german_party.csv")
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
config.Search = "SPD"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-08 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.lang= "de"
config.Output = "week_SPD_german_party.csv"
twint.run.Search(config)
df_SPD_week=pd.read_csv("week_SPD_german_party.csv")
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
config.Search = "CDU"
config.Limit = 100_000
config.Min_likes= 10
config.Since ='2021-08-08 12:00:00'
config.Until ='2021-08-18 12:00:00'
config.Store_csv = True
config.Hide_output = True
config.lang= "de"
config.Output = "week_CDU_german_party.csv"
twint.run.Search(config)
df_CDU_week=pd.read_csv("week_CDU_german_party.csv")
# Out:
# [!] No more data! Scraping will stop now.
# found 0 deleted tweets in this search.

# %%
df_LINKE_week.groupby("date").count()["id"]
# Out:
# date
# 2021-08-10    116
# 2021-08-11    307
# 2021-08-12    272
# 2021-08-13    345
# 2021-08-14    245
# 2021-08-15    289
# 2021-08-16    344
# 2021-08-17    259
# 2021-08-18    154
# Name: id, dtype: int64

# %%
plt.figure(figsize=(15,5))
plt.ylim(0,3000)

plt.ylabel("Tweet count with 10 likes")
plt.plot(df_CDU_week.groupby("date").count()["id"].index.values[1:-1], df_CDU_week.groupby("date").count()["id"].values[1:-1], label="CDU")
plt.plot(df_SPD_week.groupby("date").count()["id"].index.values[1:-1], df_SPD_week.groupby("date").count()["id"].values[1:-1], label="SPD")
plt.plot(df_Gruenen_week.groupby("date").count()["id"].index.values[1:-1], df_Gruenen_week.groupby("date").count()["id"].values[1:-1], label="Gruenen")
plt.plot(df_FDP_week[df_FDP_week["language"]=="de" ].groupby("date").count()["id"].index.values[1:-1], df_FDP_week[df_FDP_week["language"]=="de" ].groupby("date").count()["id"].values[1:-1], label="FDP")
plt.plot(df_AfD_week.groupby("date").count()["id"].index.values[1:-1], df_AfD_week.groupby("date").count()["id"].values[1:-1], label="AfD")
plt.plot(df_LINKE_week.groupby("date").count()["id"].index.values[1:-1], df_LINKE_week.groupby("date").count()["id"].values[1:-1], label="LINKE")
plt.legend()

# %%
df_LINKE_week.groupby("date").count()["id"].index.values[1:-1]
# Out:
# array(['2021-08-11', '2021-08-12', '2021-08-13', '2021-08-14',
#        '2021-08-15', '2021-08-16', '2021-08-17'], dtype=object)

# %%
df_LINKE_week.groupby("date").count()["id"].values
# Out:
# array([116, 307, 272, 345, 245, 289, 344, 259, 154])
